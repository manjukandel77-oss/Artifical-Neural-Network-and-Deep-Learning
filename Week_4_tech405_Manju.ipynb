# %% [markdown]
# # VGG 19 Architecture
#
# ## 1) Using Transfer Learning

# %%
from tensorflow.keras.applications import VGG19

pretrained_vgg = VGG19(weights='imagenet', include_top=True, input_shape=(224, 224, 3))

pretrained_vgg.summary()
# Out:
# ...
# 574710816/574710816 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %% [markdown]
# ## 2) VGG19 From Scratch

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense


INPUT_SHAPE = (224, 224, 3)
NUM_CLASSES = 1000

vgg19_scratch = Sequential([
    # Block 1
    Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=INPUT_SHAPE),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), strides=(2, 2)),

    # Block 2
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), strides=(2, 2)),

    # Block 3
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    Conv2D(256, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), strides=(2, 2)),

    # Block 4
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), strides=(2, 2)),

    # Block 5
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    Conv2D(512, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2), strides=(2, 2)),

    # Classifier Block (Fully Connected Layers)
    Flatten(),
    Dense(4096, activation='relu'),
    Dense(4096, activation='relu'),
    Dense(NUM_CLASSES, activation='softmax')
])

vgg19_scratch.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image

print("Loading VGG19 model...")
model = VGG19(weights='imagenet')

img_path = '/content/drive/MyDrive/ANN &DL/donkey.jpg'  ## Edit this for your image
img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

print("Making prediction...")
predictions = model.predict(x)

results = decode_predictions(predictions, top=3)[0]

print("\n--- RESULTS ---")
for item in results:
    print(f"{item[1]}: {item[2]*100:.2f}% confidence")
# Out:
# Loading VGG19 model...
# Making prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- RESULTS ---
# llama: 65.96% confidence
# ox: 9.86% confidence
# ibex: 5.19% confidence

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## ResNet Architecture

# %%
import kagglehub
import tensorflow as tf
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
import os

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="validation",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

train_dataset = train_dataset.map(lambda x, y: (preprocess_input(x), y))
val_dataset = val_dataset.map(lambda x, y: (preprocess_input(x), y))

print("Downloading ResNet152 Base Model...")

base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
predictions = Dense(7, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("\n--- Starting ResNet Training ---")
history = model.fit(train_dataset, validation_data=val_dataset, epochs=5)

print("\n--- ResNet Model Architecture ---")
model.summary()
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Found 1803 files belonging to 7 classes.
# Using 360 files for validation.
# ...
#
# --- Starting ResNet Training ---
# Epoch 1/5
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 73s 997ms/step - accuracy: 0.8808 - loss: 0.3768 - val_accuracy: 0.9833 - val_loss: 0.0787
# Epoch 2/5
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 295ms/step - accuracy: 0.9896 - loss: 0.0423 - val_accuracy: 0.9917 - val_loss: 0.0518
# Epoch 3/5
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.9972 - loss: 0.0219 - val_accuracy: 0.9917 - val_loss: 0.0492
# Epoch 4/5
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.9986 - loss: 0.0146 - val_accuracy: 0.9861 - val_loss: 0.0551
# Epoch 5/5
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 302ms/step - accuracy: 0.9993 - loss: 0.0116 - val_accuracy: 0.9917 - val_loss: 0.0460
#
# --- ResNet Model Architecture ---
# Model: "functional_2"
# ...

# %% [markdown]
# ## Prediction Image 1

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/Sheep.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/Sheep.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 98.58% confidence
# dogs: 0.95% confidence
# human: 0.22% confidence

# %% [markdown]
# #Prediction Image 2

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/bull.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/bull.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 80.99% confidence
# dogs: 13.13% confidence
# cars: 3.56% confidence

# %% [markdown]
# #Prediction Image 3

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/cat.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/cat.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# cats: 99.09% confidence
# horses: 0.33% confidence
# human: 0.24% confidence

# %% [markdown]
# #Prediction Image 4

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/cow.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/cow.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 95.00% confidence
# dogs: 4.38% confidence
# human: 0.40% confidence

# %% [markdown]
# #Prediction Image 5

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/dog.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/dog.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# dogs: 95.39% confidence
# horses: 4.22% confidence
# human: 0.15% confidence

# %% [markdown]
# #Prediction Image 6

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/donkey.jpg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/donkey.jpg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# dogs: 80.01% confidence
# horses: 17.03% confidence
# human: 1.88% confidence

# %% [markdown]
# #Prediction Image 7

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/fox.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/fox.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# dogs: 55.46% confidence
# horses: 34.20% confidence
# cats: 4.77% confidence

# %% [markdown]
# #Prediction Image 8

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/goat.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/goat.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 93.92% confidence
# dogs: 5.15% confidence
# human: 0.55% confidence

# %% [markdown]
# #Prediction Image 9

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/hen.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/hen.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 90.42% confidence
# cats: 4.72% confidence
# dogs: 3.44% confidence

# %% [markdown]
# #Prediction Image 10

# %%
import numpy as np
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input

import tensorflow as tf
import os
import kagglehub

path = kagglehub.dataset_download("pavansanagapati/images-dataset")
data_dir = os.path.join(path, "data", "data")
if not os.path.exists(data_dir):
    data_dir = path

BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir, validation_split=0.2, subset="training",
    seed=123, image_size=IMG_SIZE, batch_size=BATCH_SIZE
)

class_names = train_dataset.class_names

img_path = '/content/drive/MyDrive/ANN &DL/horse.jpeg'

print(f"Loading image from: {img_path}")

img = image.load_img(img_path, target_size=(224, 224))

x = image.img_to_array(img)

x = np.expand_dims(x, axis=0)

x = preprocess_input(x)

print("Making prediction with your trained ResNet152 model...")

predictions = model.predict(x)

predicted_class_idx = np.argmax(predictions[0])
predicted_class_name = class_names[predicted_class_idx]


confidence = predictions[0][predicted_class_idx]
top_indices = predictions[0].argsort()[-3:][::-1]

print("\n--- RESNET152 PREDICTION RESULTS ---")
for i in top_indices:
    class_name = class_names[i]
    confidence_score = predictions[0][i]
    print(f"{class_name}: {confidence_score*100:.2f}% confidence")
# Out:
# Using Colab cache for faster access to the 'images-dataset' dataset.
# Found 1803 files belonging to 7 classes.
# Using 1443 files for training.
# Loading image from: /content/drive/MyDrive/ANN &DL/horse.jpeg
# Making prediction with your trained ResNet152 model...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
#
# --- RESNET152 PREDICTION RESULTS ---
# horses: 99.80% confidence
# human: 0.09% confidence
# dogs: 0.06% confidence
